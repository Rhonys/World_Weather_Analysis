# %%
# Import the random module.
import random

# %%
# Import pandas
import pandas as pd

# %%
# Import the NumPy module.
import numpy as np

# %%
# Import timeit.
import timeit

# %%
import time
from datetime import datetime

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = zip(lats, lngs)

# %%
# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
len(cities)
# Out:
# 752

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e34545d0a2e379f10f04c38ef44e09cb

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dibaya
# City not found. Skipping...
# Processing Record 2 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | syracuse
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | dovolnoye
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | hihya
# Processing Record 19 of Set 1 | semnan
# Processing Record 20 of Set 1 | wangqing
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | marion
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | horsham
# Processing Record 26 of Set 1 | taoudenni
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | trapani
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | cap malheureux
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | kang
# Processing Record 39 of Set 1 | sao filipe
# Processing Record 40 of Set 1 | sinnamary
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | sao gabriel da cachoeira
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | cabedelo
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | rampur
# Processing Record 48 of Set 1 | ust-omchug
# Processing Record 49 of Set 1 | houma
# Processing Record 50 of Set 1 | sitka
# Processing Record 1 of Set 2 | micheweni
# Processing Record 2 of Set 2 | niltepec
# Processing Record 3 of Set 2 | sainte-marie
# Processing Record 4 of Set 2 | makakilo city
# Processing Record 5 of Set 2 | blantyre
# Processing Record 6 of Set 2 | narsaq
# Processing Record 7 of Set 2 | deputatskiy
# Processing Record 8 of Set 2 | santa barbara
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | kudahuvadhoo
# Processing Record 12 of Set 2 | vagamo
# Processing Record 13 of Set 2 | mtambile
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | mount gambier
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | srednekolymsk
# Processing Record 19 of Set 2 | guangyuan
# Processing Record 20 of Set 2 | vila velha
# Processing Record 21 of Set 2 | guerrero negro
# Processing Record 22 of Set 2 | del rio
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | dafeng
# Processing Record 25 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 2 | khartoum
# Processing Record 27 of Set 2 | niquelandia
# Processing Record 28 of Set 2 | parrita
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | labytnangi
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | san patricio
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | lapa
# Processing Record 36 of Set 2 | westport
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | iquitos
# Processing Record 39 of Set 2 | boddam
# Processing Record 40 of Set 2 | lorengau
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | grindavik
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | zeya
# Processing Record 47 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | sarahan
# Processing Record 50 of Set 2 | qaqortoq
# Processing Record 1 of Set 3 | wake forest
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | doka
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | usak
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 3 | bambous virieux
# Processing Record 12 of Set 3 | ostrovnoy
# Processing Record 13 of Set 3 | tommot
# Processing Record 14 of Set 3 | henties bay
# Processing Record 15 of Set 3 | myanaung
# Processing Record 16 of Set 3 | winona
# Processing Record 17 of Set 3 | bucerias
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | thinadhoo
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | finschhafen
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | tigre
# Processing Record 24 of Set 3 | moron
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | vao
# Processing Record 28 of Set 3 | taltal
# Processing Record 29 of Set 3 | ca mau
# Processing Record 30 of Set 3 | tual
# Processing Record 31 of Set 3 | buenaventura
# Processing Record 32 of Set 3 | eureka
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | freeport
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | codrington
# Processing Record 37 of Set 3 | swindon
# Processing Record 38 of Set 3 | killybegs
# Processing Record 39 of Set 3 | vestmanna
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | hornepayne
# Processing Record 42 of Set 3 | evensk
# Processing Record 43 of Set 3 | shahrud
# Processing Record 44 of Set 3 | voznesenskaya
# Processing Record 45 of Set 3 | hofn
# Processing Record 46 of Set 3 | birobidzhan
# Processing Record 47 of Set 3 | kampot
# Processing Record 48 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | agirish
# Processing Record 2 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 3 of Set 4 | dunedin
# Processing Record 4 of Set 4 | verkhovazhye
# Processing Record 5 of Set 4 | wukari
# Processing Record 6 of Set 4 | los arabos
# Processing Record 7 of Set 4 | oleksandrivka
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | abashiri
# Processing Record 10 of Set 4 | comodoro rivadavia
# Processing Record 11 of Set 4 | sambava
# Processing Record 12 of Set 4 | bubaque
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | zapolyarnyy
# Processing Record 15 of Set 4 | homun
# Processing Record 16 of Set 4 | bethel
# Processing Record 17 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 4 | tortoli
# Processing Record 19 of Set 4 | anadyr
# Processing Record 20 of Set 4 | cayenne
# Processing Record 21 of Set 4 | zyryanka
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | pavda
# City not found. Skipping...
# Processing Record 24 of Set 4 | cananeia
# Processing Record 25 of Set 4 | avera
# Processing Record 26 of Set 4 | aykhal
# Processing Record 27 of Set 4 | aracati
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | saskylakh
# Processing Record 30 of Set 4 | ampanihy
# Processing Record 31 of Set 4 | terenos
# Processing Record 32 of Set 4 | puerto carreno
# Processing Record 33 of Set 4 | nanortalik
# Processing Record 34 of Set 4 | kapuskasing
# Processing Record 35 of Set 4 | teluk nibung
# Processing Record 36 of Set 4 | chinhoyi
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | port hedland
# Processing Record 40 of Set 4 | atuona
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 4 | acapulco
# Processing Record 43 of Set 4 | carbonia
# Processing Record 44 of Set 4 | los llanos de aridane
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | chapais
# Processing Record 47 of Set 4 | itarema
# Processing Record 48 of Set 4 | ketchikan
# Processing Record 49 of Set 4 | dumas
# Processing Record 50 of Set 4 | constitucion
# Processing Record 1 of Set 5 | asyut
# Processing Record 2 of Set 5 | padang
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 5 | axim
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | ekhabi
# Processing Record 7 of Set 5 | churapcha
# Processing Record 8 of Set 5 | port-gentil
# Processing Record 9 of Set 5 | calabozo
# Processing Record 10 of Set 5 | arroyo
# Processing Record 11 of Set 5 | portland
# Processing Record 12 of Set 5 | tynda
# Processing Record 13 of Set 5 | copiapo
# Processing Record 14 of Set 5 | pamekasan
# Processing Record 15 of Set 5 | northam
# Processing Record 16 of Set 5 | mehamn
# Processing Record 17 of Set 5 | tara
# Processing Record 18 of Set 5 | fairbanks
# Processing Record 19 of Set 5 | prince rupert
# Processing Record 20 of Set 5 | kawalu
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | pemangkat
# Processing Record 23 of Set 5 | yandoon
# City not found. Skipping...
# Processing Record 24 of Set 5 | bhadrak
# Processing Record 25 of Set 5 | kongoussi
# Processing Record 26 of Set 5 | cabo san lucas
# Processing Record 27 of Set 5 | ancud
# Processing Record 28 of Set 5 | resistencia
# Processing Record 29 of Set 5 | little current
# Processing Record 30 of Set 5 | san buenaventura
# Processing Record 31 of Set 5 | penha
# Processing Record 32 of Set 5 | kachug
# Processing Record 33 of Set 5 | pangody
# Processing Record 34 of Set 5 | touros
# Processing Record 35 of Set 5 | san vito
# Processing Record 36 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 5 | liverpool
# Processing Record 38 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 5 | ojinaga
# Processing Record 40 of Set 5 | lata
# Processing Record 41 of Set 5 | iralaya
# Processing Record 42 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 5 | salina cruz
# Processing Record 44 of Set 5 | guiglo
# Processing Record 45 of Set 5 | mahebourg
# Processing Record 46 of Set 5 | saint george
# Processing Record 47 of Set 5 | rawson
# Processing Record 48 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 5 | asau
# Processing Record 50 of Set 5 | roblin
# Processing Record 1 of Set 6 | chuy
# Processing Record 2 of Set 6 | banjar
# Processing Record 3 of Set 6 | abbeville
# Processing Record 4 of Set 6 | fortuna
# Processing Record 5 of Set 6 | agha jari
# City not found. Skipping...
# Processing Record 6 of Set 6 | iguai
# Processing Record 7 of Set 6 | turayf
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | namatanai
# Processing Record 10 of Set 6 | muros
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | kuusamo
# Processing Record 13 of Set 6 | denpasar
# Processing Record 14 of Set 6 | punta arenas
# Processing Record 15 of Set 6 | luderitz
# Processing Record 16 of Set 6 | kirensk
# Processing Record 17 of Set 6 | key biscayne
# Processing Record 18 of Set 6 | topeka
# Processing Record 19 of Set 6 | half moon bay
# Processing Record 20 of Set 6 | alice springs
# Processing Record 21 of Set 6 | nara
# Processing Record 22 of Set 6 | marystown
# Processing Record 23 of Set 6 | puerto colombia
# Processing Record 24 of Set 6 | esperance
# Processing Record 25 of Set 6 | moose factory
# Processing Record 26 of Set 6 | edd
# Processing Record 27 of Set 6 | sao joao da barra
# Processing Record 28 of Set 6 | port macquarie
# Processing Record 29 of Set 6 | palmas
# Processing Record 30 of Set 6 | fairfield
# Processing Record 31 of Set 6 | ahipara
# Processing Record 32 of Set 6 | harsud
# Processing Record 33 of Set 6 | koson
# Processing Record 34 of Set 6 | lao cai
# Processing Record 35 of Set 6 | ibate
# Processing Record 36 of Set 6 | hirara
# Processing Record 37 of Set 6 | vikhorevka
# Processing Record 38 of Set 6 | ponnani
# Processing Record 39 of Set 6 | geraldton
# Processing Record 40 of Set 6 | san cristobal
# Processing Record 41 of Set 6 | flic en flac
# Processing Record 42 of Set 6 | loandjili
# Processing Record 43 of Set 6 | eyl
# Processing Record 44 of Set 6 | provideniya
# Processing Record 45 of Set 6 | ranong
# Processing Record 46 of Set 6 | porterville
# Processing Record 47 of Set 6 | kamaishi
# Processing Record 48 of Set 6 | bosobolo
# Processing Record 49 of Set 6 | port lincoln
# Processing Record 50 of Set 6 | pevek
# Processing Record 1 of Set 7 | cockburn town
# Processing Record 2 of Set 7 | tasiilaq
# Processing Record 3 of Set 7 | souillac
# Processing Record 4 of Set 7 | kaeo
# Processing Record 5 of Set 7 | starkville
# Processing Record 6 of Set 7 | ucluelet
# Processing Record 7 of Set 7 | maryville
# Processing Record 8 of Set 7 | san rafael
# Processing Record 9 of Set 7 | faanui
# Processing Record 10 of Set 7 | san andres
# Processing Record 11 of Set 7 | chameza
# City not found. Skipping...
# Processing Record 12 of Set 7 | grand-lahou
# Processing Record 13 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 7 | huanren
# Processing Record 15 of Set 7 | edgewater
# Processing Record 16 of Set 7 | carson city
# Processing Record 17 of Set 7 | hearst
# Processing Record 18 of Set 7 | turbat
# Processing Record 19 of Set 7 | storslett
# Processing Record 20 of Set 7 | leningradskiy
# Processing Record 21 of Set 7 | mahina
# Processing Record 22 of Set 7 | noumea
# Processing Record 23 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 24 of Set 7 | hillsborough
# Processing Record 25 of Set 7 | rovaniemi
# Processing Record 26 of Set 7 | mazatlan
# Processing Record 27 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 7 | kisangani
# Processing Record 29 of Set 7 | bereda
# Processing Record 30 of Set 7 | galle
# Processing Record 31 of Set 7 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 32 of Set 7 | binga
# Processing Record 33 of Set 7 | lokomotivnyy
# Processing Record 34 of Set 7 | mega
# Processing Record 35 of Set 7 | pangkalanbuun
# Processing Record 36 of Set 7 | morondava
# Processing Record 37 of Set 7 | nanga eboko
# Processing Record 38 of Set 7 | saint-augustin
# Processing Record 39 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 7 | maceio
# Processing Record 41 of Set 7 | segou
# Processing Record 42 of Set 7 | alofi
# Processing Record 43 of Set 7 | labuhan
# Processing Record 44 of Set 7 | benguela
# Processing Record 45 of Set 7 | roald
# Processing Record 46 of Set 7 | mikhaylovka
# Processing Record 47 of Set 7 | olinda
# Processing Record 48 of Set 7 | linjiang
# Processing Record 49 of Set 7 | high level
# Processing Record 50 of Set 7 | lubango
# Processing Record 1 of Set 8 | vertou
# Processing Record 2 of Set 8 | srikakulam
# Processing Record 3 of Set 8 | bud
# Processing Record 4 of Set 8 | saldanha
# Processing Record 5 of Set 8 | grand gaube
# Processing Record 6 of Set 8 | amga
# Processing Record 7 of Set 8 | texarkana
# Processing Record 8 of Set 8 | gora kalwaria
# Processing Record 9 of Set 8 | oistins
# Processing Record 10 of Set 8 | katsuura
# Processing Record 11 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 8 | larsnes
# Processing Record 13 of Set 8 | shangrao
# Processing Record 14 of Set 8 | ashland
# Processing Record 15 of Set 8 | santiago del estero
# Processing Record 16 of Set 8 | iqaluit
# Processing Record 17 of Set 8 | sangar
# Processing Record 18 of Set 8 | rock island
# Processing Record 19 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 8 | ust-ishim
# Processing Record 21 of Set 8 | yulara
# Processing Record 22 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 23 of Set 8 | salalah
# Processing Record 24 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 8 | nouadhibou
# Processing Record 26 of Set 8 | saint andrews
# Processing Record 27 of Set 8 | great bend
# Processing Record 28 of Set 8 | riyadh
# Processing Record 29 of Set 8 | tutoia
# Processing Record 30 of Set 8 | mao
# Processing Record 31 of Set 8 | lafiagi
# Processing Record 32 of Set 8 | isangel
# Processing Record 33 of Set 8 | ust-kuyga
# Processing Record 34 of Set 8 | bay roberts
# Processing Record 35 of Set 8 | moryakovskiy zaton
# Processing Record 36 of Set 8 | tessalit
# Processing Record 37 of Set 8 | palm coast
# Processing Record 38 of Set 8 | aginskoye
# Processing Record 39 of Set 8 | kangaatsiaq
# Processing Record 40 of Set 8 | cerkezkoy
# Processing Record 41 of Set 8 | flinders
# Processing Record 42 of Set 8 | shadegan
# Processing Record 43 of Set 8 | altamont
# Processing Record 44 of Set 8 | morro bay
# Processing Record 45 of Set 8 | calvinia
# Processing Record 46 of Set 8 | pavlovskiy
# Processing Record 47 of Set 8 | santa maria
# Processing Record 48 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 8 | beidao
# Processing Record 50 of Set 8 | cairns
# Processing Record 1 of Set 9 | aklavik
# Processing Record 2 of Set 9 | clyde river
# Processing Record 3 of Set 9 | quatre cocos
# Processing Record 4 of Set 9 | ngunguru
# Processing Record 5 of Set 9 | honiara
# Processing Record 6 of Set 9 | mossendjo
# Processing Record 7 of Set 9 | barcelos
# Processing Record 8 of Set 9 | pamanukan
# Processing Record 9 of Set 9 | ahuimanu
# Processing Record 10 of Set 9 | atambua
# Processing Record 11 of Set 9 | jalu
# Processing Record 12 of Set 9 | belmonte
# Processing Record 13 of Set 9 | kindu
# Processing Record 14 of Set 9 | norfolk
# Processing Record 15 of Set 9 | karratha
# Processing Record 16 of Set 9 | oktyabrskiy
# Processing Record 17 of Set 9 | lazaro cardenas
# Processing Record 18 of Set 9 | maniitsoq
# Processing Record 19 of Set 9 | stromness
# Processing Record 20 of Set 9 | jiuquan
# Processing Record 21 of Set 9 | vestmannaeyjar
# Processing Record 22 of Set 9 | minsk
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | gladstone
# Processing Record 25 of Set 9 | mount isa
# Processing Record 26 of Set 9 | mazara del vallo
# Processing Record 27 of Set 9 | imeni poliny osipenko
# Processing Record 28 of Set 9 | sokolo
# Processing Record 29 of Set 9 | ilhabela
# Processing Record 30 of Set 9 | tazmalt
# Processing Record 31 of Set 9 | yishui
# Processing Record 32 of Set 9 | abrau-dyurso
# Processing Record 33 of Set 9 | lethem
# Processing Record 34 of Set 9 | santa ines
# Processing Record 35 of Set 9 | port augusta
# Processing Record 36 of Set 9 | unity
# Processing Record 37 of Set 9 | kununurra
# Processing Record 38 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 9 | verkhnyaya inta
# Processing Record 40 of Set 9 | dongsheng
# Processing Record 41 of Set 9 | birin
# Processing Record 42 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 9 | agua verde
# Processing Record 45 of Set 9 | novocheremshansk
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | malanje
# Processing Record 48 of Set 9 | meadow lake
# Processing Record 49 of Set 9 | saint-pierre
# Processing Record 50 of Set 9 | honningsvag
# Processing Record 1 of Set 10 | sepolno krajenskie
# Processing Record 2 of Set 10 | puerto del rosario
# Processing Record 3 of Set 10 | aygehovit
# Processing Record 4 of Set 10 | havre-saint-pierre
# Processing Record 5 of Set 10 | kovdor
# Processing Record 6 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 10 | kavaratti
# Processing Record 8 of Set 10 | sovetskiy
# Processing Record 9 of Set 10 | kovernino
# Processing Record 10 of Set 10 | peoria
# Processing Record 11 of Set 10 | borzya
# Processing Record 12 of Set 10 | byron bay
# Processing Record 13 of Set 10 | bonthe
# Processing Record 14 of Set 10 | ternate
# Processing Record 15 of Set 10 | scottsboro
# Processing Record 16 of Set 10 | san blas
# Processing Record 17 of Set 10 | hirata
# Processing Record 18 of Set 10 | kamenka
# Processing Record 19 of Set 10 | ipeti
# City not found. Skipping...
# Processing Record 20 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 10 | watertown
# Processing Record 22 of Set 10 | hamilton
# Processing Record 23 of Set 10 | kaharlyk
# Processing Record 24 of Set 10 | brae
# Processing Record 25 of Set 10 | komsomolskiy
# Processing Record 26 of Set 10 | waverly
# Processing Record 27 of Set 10 | miyako
# Processing Record 28 of Set 10 | sibolga
# Processing Record 29 of Set 10 | homer
# Processing Record 30 of Set 10 | praya
# Processing Record 31 of Set 10 | ziro
# Processing Record 32 of Set 10 | sur
# Processing Record 33 of Set 10 | uyemskiy
# Processing Record 34 of Set 10 | luwuk
# Processing Record 35 of Set 10 | saint anthony
# Processing Record 36 of Set 10 | terrace bay
# Processing Record 37 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 10 | tilichiki
# Processing Record 39 of Set 10 | chornyanka
# Processing Record 40 of Set 10 | thamaga
# Processing Record 41 of Set 10 | vila franca do campo
# Processing Record 42 of Set 10 | puurmani
# Processing Record 43 of Set 10 | les escoumins
# Processing Record 44 of Set 10 | trat
# Processing Record 45 of Set 10 | porbandar
# Processing Record 46 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 10 | bontang
# Processing Record 48 of Set 10 | beringovskiy
# Processing Record 49 of Set 10 | urumqi
# Processing Record 50 of Set 10 | tanabe
# Processing Record 1 of Set 11 | sayyan
# Processing Record 2 of Set 11 | bonao
# Processing Record 3 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 11 | chumikan
# Processing Record 5 of Set 11 | novosheshminsk
# Processing Record 6 of Set 11 | tuatapere
# Processing Record 7 of Set 11 | luganville
# Processing Record 8 of Set 11 | tautira
# Processing Record 9 of Set 11 | maniago
# Processing Record 10 of Set 11 | barsovo
# Processing Record 11 of Set 11 | waingapu
# Processing Record 12 of Set 11 | batagay-alyta
# Processing Record 13 of Set 11 | skovorodino
# Processing Record 14 of Set 11 | nome
# Processing Record 15 of Set 11 | coquimbo
# Processing Record 16 of Set 11 | tevaitoa
# Processing Record 17 of Set 11 | christchurch
# Processing Record 18 of Set 11 | salta
# Processing Record 19 of Set 11 | el dorado
# Processing Record 20 of Set 11 | nador
# Processing Record 21 of Set 11 | dudinka
# Processing Record 22 of Set 11 | voznesenye
# Processing Record 23 of Set 11 | marsa matruh
# Processing Record 24 of Set 11 | alta floresta
# Processing Record 25 of Set 11 | panara
# Processing Record 26 of Set 11 | husavik
# Processing Record 27 of Set 11 | marquette
# Processing Record 28 of Set 11 | pringsewu
# Processing Record 29 of Set 11 | san ramon
# Processing Record 30 of Set 11 | yumen
# Processing Record 31 of Set 11 | njeru
# Processing Record 32 of Set 11 | nakamura
# Processing Record 33 of Set 11 | viedma
# Processing Record 34 of Set 11 | andenes
# Processing Record 35 of Set 11 | kandrian
# Processing Record 36 of Set 11 | lagos
# Processing Record 37 of Set 11 | aquidaba
# Processing Record 38 of Set 11 | samarai
# Processing Record 39 of Set 11 | podosinovets
# Processing Record 40 of Set 11 | black river
# Processing Record 41 of Set 11 | upington
# Processing Record 42 of Set 11 | gondar
# Processing Record 43 of Set 11 | borogontsy
# Processing Record 44 of Set 11 | lagoa
# Processing Record 45 of Set 11 | korla
# Processing Record 46 of Set 11 | seoul
# Processing Record 47 of Set 11 | tombouctou
# Processing Record 48 of Set 11 | belmopan
# Processing Record 49 of Set 11 | ryotsu
# Processing Record 50 of Set 11 | ormond beach
# Processing Record 1 of Set 12 | egvekinot
# Processing Record 2 of Set 12 | lichinga
# Processing Record 3 of Set 12 | biak
# Processing Record 4 of Set 12 | taylor
# Processing Record 5 of Set 12 | praia da vitoria
# Processing Record 6 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 7 of Set 12 | fereydunshahr
# Processing Record 8 of Set 12 | bangsund
# Processing Record 9 of Set 12 | medea
# Processing Record 10 of Set 12 | college
# Processing Record 11 of Set 12 | borovoy
# Processing Record 12 of Set 12 | russell
# Processing Record 13 of Set 12 | igurusi
# Processing Record 14 of Set 12 | solnechnyy
# Processing Record 15 of Set 12 | drawsko pomorskie
# Processing Record 16 of Set 12 | makung
# City not found. Skipping...
# Processing Record 17 of Set 12 | san quintin
# Processing Record 18 of Set 12 | haines junction
# Processing Record 19 of Set 12 | catarman
# Processing Record 20 of Set 12 | sungaipenuh
# Processing Record 21 of Set 12 | boende
# Processing Record 22 of Set 12 | victor harbor
# Processing Record 23 of Set 12 | sarangani
# Processing Record 24 of Set 12 | haverfordwest
# Processing Record 25 of Set 12 | ponta delgada
# Processing Record 26 of Set 12 | palmeirais
# Processing Record 27 of Set 12 | tarakan
# Processing Record 28 of Set 12 | monrovia
# Processing Record 29 of Set 12 | hasaki
# Processing Record 30 of Set 12 | biltine
# Processing Record 31 of Set 12 | fort nelson
# Processing Record 32 of Set 12 | boueni
# Processing Record 33 of Set 12 | kitakata
# Processing Record 34 of Set 12 | lakes entrance
# Processing Record 35 of Set 12 | carndonagh
# Processing Record 36 of Set 12 | ulladulla
# Processing Record 37 of Set 12 | hay river
# Processing Record 38 of Set 12 | woodstock
# Processing Record 39 of Set 12 | shitanjing
# Processing Record 40 of Set 12 | tangara
# Processing Record 41 of Set 12 | bat yam
# Processing Record 42 of Set 12 | nizwa
# Processing Record 43 of Set 12 | nizhniy kuranakh
# Processing Record 44 of Set 12 | kiknur
# Processing Record 45 of Set 12 | pointe michel
# Processing Record 46 of Set 12 | ola
# Processing Record 47 of Set 12 | rudbar
# Processing Record 48 of Set 12 | maungatapere
# Processing Record 49 of Set 12 | saint-joseph
# Processing Record 50 of Set 12 | huaibei
# Processing Record 1 of Set 13 | mountain home
# Processing Record 2 of Set 13 | harper
# Processing Record 3 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 13 | havelock
# Processing Record 5 of Set 13 | faya
# Processing Record 6 of Set 13 | keroka
# Processing Record 7 of Set 13 | palmer
# Processing Record 8 of Set 13 | bantogon
# Processing Record 9 of Set 13 | smidovich
# Processing Record 10 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 13 | namwala
# Processing Record 12 of Set 13 | joao pinheiro
# Processing Record 13 of Set 13 | sisimiut
# Processing Record 14 of Set 13 | hildburghausen
# Processing Record 15 of Set 13 | paamiut
# Processing Record 16 of Set 13 | leshan
# Processing Record 17 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 18 of Set 13 | ariano irpino
# Processing Record 19 of Set 13 | antsohihy
# Processing Record 20 of Set 13 | klaksvik
# Processing Record 21 of Set 13 | glenwood springs
# Processing Record 22 of Set 13 | celestun
# Processing Record 23 of Set 13 | amboasary
# Processing Record 24 of Set 13 | glendive
# Processing Record 25 of Set 13 | saint-francois
# Processing Record 26 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 13 | valparaiso
# Processing Record 28 of Set 13 | santa pola
# Processing Record 29 of Set 13 | tahta
# Processing Record 30 of Set 13 | afyonkarahisar
# Processing Record 31 of Set 13 | skegness
# Processing Record 32 of Set 13 | cocorit
# Processing Record 33 of Set 13 | baghdad
# Processing Record 34 of Set 13 | ambon
# Processing Record 35 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 36 of Set 13 | coihaique
# Processing Record 37 of Set 13 | svetlyy
# Processing Record 38 of Set 13 | ginda
# Processing Record 39 of Set 13 | bathsheba
# Processing Record 40 of Set 13 | dugna
# City not found. Skipping...
# Processing Record 41 of Set 13 | khasan
# Processing Record 42 of Set 13 | hovd
# Processing Record 43 of Set 13 | awjilah
# Processing Record 44 of Set 13 | laishevo
# Processing Record 45 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 13 | omsukchan
# Processing Record 47 of Set 13 | vlasim
# Processing Record 48 of Set 13 | westerland
# Processing Record 49 of Set 13 | chiusi
# Processing Record 50 of Set 13 | durban
# Processing Record 1 of Set 14 | slyudyanka
# Processing Record 2 of Set 14 | gisborne
# Processing Record 3 of Set 14 | hobyo
# Processing Record 4 of Set 14 | rio gallegos
# Processing Record 5 of Set 14 | sehithwa
# Processing Record 6 of Set 14 | bendigo
# Processing Record 7 of Set 14 | kedrovyy
# Processing Record 8 of Set 14 | marawi
# Processing Record 9 of Set 14 | south lake tahoe
# Processing Record 10 of Set 14 | kasongo-lunda
# Processing Record 11 of Set 14 | tema
# Processing Record 12 of Set 14 | meulaboh
# Processing Record 13 of Set 14 | bayan
# Processing Record 14 of Set 14 | ivdel
# Processing Record 15 of Set 14 | kalakamati
# Processing Record 16 of Set 14 | mapiripan
# Processing Record 17 of Set 14 | longkou
# Processing Record 18 of Set 14 | mayo
# Processing Record 19 of Set 14 | tabuk
# Processing Record 20 of Set 14 | gunnedah
# Processing Record 21 of Set 14 | piacabucu
# Processing Record 22 of Set 14 | neiafu
# Processing Record 23 of Set 14 | wenzhou
# Processing Record 24 of Set 14 | big spring
# Processing Record 25 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 26 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 14 | punta alta
# Processing Record 28 of Set 14 | alyangula
# Processing Record 29 of Set 14 | nemuro
# Processing Record 30 of Set 14 | michigan city
# Processing Record 31 of Set 14 | puttur
# Processing Record 32 of Set 14 | rumoi
# Processing Record 33 of Set 14 | sawakin
# Processing Record 34 of Set 14 | buraydah
# Processing Record 35 of Set 14 | santa cruz
# Processing Record 36 of Set 14 | bintulu
# Processing Record 37 of Set 14 | nelson bay
# Processing Record 38 of Set 14 | itaituba
# Processing Record 39 of Set 14 | moranbah
# Processing Record 40 of Set 14 | zhigansk
# Processing Record 41 of Set 14 | elizabeth city
# Processing Record 42 of Set 14 | mbacke
# City not found. Skipping...
# Processing Record 43 of Set 14 | ramos arizpe
# Processing Record 44 of Set 14 | lasa
# Processing Record 45 of Set 14 | cintalapa
# Processing Record 46 of Set 14 | fuxin
# Processing Record 47 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 14 | ambulu
# Processing Record 49 of Set 14 | mookane
# Processing Record 50 of Set 14 | kishtwar
# Processing Record 1 of Set 15 | arawa
# Processing Record 2 of Set 15 | usinsk
# Processing Record 3 of Set 15 | ballina
# Processing Record 4 of Set 15 | novaya igirma
# Processing Record 5 of Set 15 | kauhajoki
# Processing Record 6 of Set 15 | lyuban
# Processing Record 7 of Set 15 | panorama
# Processing Record 8 of Set 15 | port said
# Processing Record 9 of Set 15 | namibe
# Processing Record 10 of Set 15 | moreira sales
# Processing Record 11 of Set 15 | klyuchi
# Processing Record 12 of Set 15 | wanning
# Processing Record 13 of Set 15 | trairi
# Processing Record 14 of Set 15 | olafsvik
# Processing Record 15 of Set 15 | meyrin
# Processing Record 16 of Set 15 | tchibanga
# Processing Record 17 of Set 15 | barao de melgaco
# Processing Record 18 of Set 15 | saint-georges
# Processing Record 19 of Set 15 | kluang
# Processing Record 20 of Set 15 | kyshtovka
# Processing Record 21 of Set 15 | cozumel
# Processing Record 22 of Set 15 | vizinga
# Processing Record 23 of Set 15 | thoen
# Processing Record 24 of Set 15 | san policarpo
# Processing Record 25 of Set 15 | north myrtle beach
# Processing Record 26 of Set 15 | torit
# Processing Record 27 of Set 15 | pasni
# Processing Record 28 of Set 15 | ipora
# Processing Record 29 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 15 | lavrentiya
# Processing Record 32 of Set 15 | weinan
# Processing Record 33 of Set 15 | tadine
# Processing Record 34 of Set 15 | buala
# Processing Record 35 of Set 15 | gorkovskoye
# City not found. Skipping...
# Processing Record 36 of Set 15 | aksarka
# Processing Record 37 of Set 15 | nishihara
# Processing Record 38 of Set 15 | urengoy
# Processing Record 39 of Set 15 | corning
# Processing Record 40 of Set 15 | peniche
# Processing Record 41 of Set 15 | guanica
# Processing Record 42 of Set 15 | diego de almagro
# Processing Record 43 of Set 15 | atuntaqui
# Processing Record 44 of Set 15 | sal
# Processing Record 45 of Set 15 | vereeniging
# Processing Record 46 of Set 15 | sioux lookout
# Processing Record 47 of Set 15 | lucapa
# Processing Record 48 of Set 15 | dubai
# Processing Record 49 of Set 15 | praia
# Processing Record 50 of Set 15 | tshela
# Processing Record 1 of Set 16 | wisconsin rapids
# Processing Record 2 of Set 16 | domoni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cidreira      BR -30.1811  -50.2056     75.18        78           3
# 1        Hobart      AU -42.8794  147.3294     61.11        63          75
# 2      Syracuse      IT  37.0881   15.2792     53.89        63           0
# 3  Kruisfontein      ZA -34.0033   24.7314     61.83        86          41
# 4   Yellowknife      CA  62.4560 -114.3525     -8.59        81          75
# 5     Carnarvon      AU -24.8667  113.6333     78.87        73          75
# 6         Vaini      TO -21.2000 -175.2000     81.52        81          83
# 7   Port Alfred      ZA -33.5906   26.8910     70.48        80          87
# 8    Butaritari      KI   3.0707  172.7902     81.37        79          30
# 9     Dovolnoye      RU  54.4958   79.6671    -22.54       100          44
#
#    Wind Speed Current Description
# 0       18.10           clear sky
# 1        8.05       broken clouds
# 2        3.58           clear sky
# 3        2.35    scattered clouds
# 4       11.50       broken clouds
# 5        8.05       broken clouds
# 6       21.88       broken clouds
# 7        8.32     overcast clouds
# 8       17.90    scattered clouds
# 9        5.03    scattered clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_file, index_label="City_ID")
